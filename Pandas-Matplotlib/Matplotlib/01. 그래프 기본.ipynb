# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터를 시각화 할 수 있는 데이터

# %% [markdown]
# ## 01. 그래프 기본

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x000001694EAF08B0>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y)
plt.title('LineGraph')
# Out:
# Text(0.5, 1.0, 'LineGraph')

# %%
plt.plot(x,y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# C:\Users\panda\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\panda\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\panda\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\panda\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\panda\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\panda\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 형상을 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['cmr10',
#  'cmss10',
#  'cmmi10',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'STIXSizeFiveSym',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXSizeFourSym',
#  'cmsy10',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'DejaVu Serif Display',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Sans Display',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'cmb10',
#  'STIXSizeFourSym',
#  'cmex10',
#  'STIXSizeTwoSym',
#  'STIXSizeOneSym',
#  'cmtt10',
#  'MV Boli',
#  'High Tower Text',
#  'Lucida Sans Typewriter',
#  'Rockwell',
#  'Viner Hand ITC',
#  'SimSun',
#  'Trebuchet MS',
#  'Bell MT',
#  'NewJumja',
#  'Segoe UI Symbol',
#  'Garamond',
#  'Niagara Solid',
#  'Century Schoolbook',
#  'Poor Richard',
#  'Arial',
#  'Snap ITC',
#  'HYGraphic-Medium',
#  'Parchment',
#  'Goudy Stout',
#  'Lucida Sans Unicode',
#  'Lucida Bright',
#  'Stencil',
#  'Calisto MT',
#  'Leelawadee UI',
#  'Book Antiqua',
#  'Haettenschweiler',
#  'Imprint MT Shadow',
#  'Kunstler Script',
#  'Gill Sans Ultra Bold',
#  'Gulim',
#  'Trebuchet MS',
#  'Gill Sans Ultra Bold Condensed',
#  'Agency FB',
#  'Franklin Gothic Medium',
#  'Lucida Bright',
#  'Segoe UI',
#  'Times New Roman',
#  'Niagara Solid',
#  'Arial',
#  'Microsoft New Tai Lue',
#  'Pyunji R',
#  'Lucida Fax',
#  'Segoe UI Historic',
#  'Franklin Gothic Book',
#  'Webdings',
#  'Corbel',
#  'Franklin Gothic Medium',
#  'Microsoft Tai Le',
#  'Segoe UI',
#  'Franklin Gothic Medium',
#  'Bodoni MT',
#  'Microsoft YaHei',
#  'Century Gothic',
#  'Calisto MT',
#  'Verdana',
#  'Segoe Print',
#  'Microsoft Himalaya',
#  'Trebuchet MS',
#  'Palatino Linotype',
#  'Berlin Sans FB Demi',
#  'Pristina',
#  'Comic Sans MS',
#  'Rockwell Condensed',
#  'Felix Titling',
#  'Cambria',
#  'HyhwpEQ',
#  'Garamond',
#  'Times New Roman',
#  'Yet R',
#  'Candara',
#  'Niagara Engraved',
#  'Garamond',
#  'Baskerville Old Face',
#  'High Tower Text',
#  'Georgia',
#  'HCR Batang',
#  'Candara',
#  'Corbel',
#  'Gill Sans MT',
#  'Calibri',
#  'Segoe Print',
#  'Palace Script MT',
#  'Bookman Old Style',
#  'High Tower Text',
#  'Lucida Console',
#  'Palatino Linotype',
#  'Segoe UI Emoji',
#  'Rockwell',
#  'Georgia',
#  'Gill Sans MT Ext Condensed Bold',
#  'Harrington',
#  'HoloLens MDL2 Assets',
#  'Lucida Bright',
#  'Comic Sans MS',
#  'Californian FB',
#  'Eras Light ITC',
#  'MS Gothic',
#  'Lucida Sans Typewriter',
#  'New Gulim',
#  'Gloucester MT Extra Condensed',
#  'Microsoft Uighur',
#  'Berlin Sans FB',
#  'Consolas',
#  'Rockwell',
#  'Segoe UI',
#  'Perpetua Titling MT',
#  'Microsoft JhengHei',
#  'Berlin Sans FB',
#  'HYSinMyeongJo-Medium',
#  'HYPMokGak-Bold',
#  'Verdana',
#  'Courier New',
#  'Constantia',
#  'Arial',
#  'Gill Sans MT',
#  'Consolas',
#  'Berlin Sans FB',
#  'Palatino Linotype',
#  'Gill Sans MT Condensed',
#  'Microsoft YaHei',
#  'Agency FB',
#  'Calisto MT',
#  'Cascadia Code',
#  'Calibri',
#  'Malgun Gothic',
#  'Microsoft Sans Serif',
#  'Elephant',
#  'Chiller',
#  'Eras Medium ITC',
#  'Dubai',
#  'Lucida Sans',
#  'Viner Hand ITC',
#  'Leelawadee',
#  'HYPost-Light',
#  'Harrington',
#  'Footlight MT Light',
#  'Arial',
#  'Magic R',
#  'Perpetua',
#  'Sitka Small',
#  'Lucida Sans',
#  'Edwardian Script ITC',
#  'Lucida Sans',
#  'Bookman Old Style',
#  'Gill Sans MT',
#  'Lucida Sans',
#  'MS Outlook',
#  'Gabriola',
#  'Lucida Sans Typewriter',
#  'Curlz MT',
#  'Book Antiqua',
#  'Californian FB',
#  'Kristen ITC',
#  'Century Schoolbook',
#  'French Script MT',
#  'Perpetua Titling MT',
#  'Franklin Gothic Book',
#  'Segoe UI',
#  'Arial Rounded MT Bold',
#  'Dubai',
#  'Gigi',
#  'Script MT Bold',
#  'Ebrima',
#  'Yu Gothic',
#  'Segoe Script',
#  'HYShortSamul-Medium',
#  'Jokerman',
#  'Corbel',
#  'Book Antiqua',
#  'Gill Sans MT Ext Condensed Bold',
#  'MS Reference Specialty',
#  'Franklin Gothic Heavy',
#  'Nirmala UI',
#  'Lucida Fax',
#  'Franklin Gothic Medium Cond',
#  'MingLiU-ExtB',
#  'MV Boli',
#  'Cambria',
#  'Book Antiqua',
#  'HYMyeongJo-Extra',
#  'Georgia',
#  'MoeumT R',
#  'Engravers MT',
#  'Copperplate Gothic Light',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Microsoft New Tai Lue',
#  'Gill Sans MT',
#  'Juice ITC',
#  'Microsoft New Tai Lue',
#  'HyhwpEQ',
#  'Segoe UI',
#  'New Gulim',
#  'Microsoft PhagsPa',
#  'Leelawadee',
#  'Microsoft Yi Baiti',
#  'Georgia',
#  'Candara',
#  'Garamond',
#  'Californian FB',
#  'Eras Medium ITC',
#  'Lucida Bright',
#  'HYGothic-Extra',
#  'Century Schoolbook',
#  'Niagara Engraved',
#  'Myanmar Text',
#  'Bell MT',
#  'Cooper Black',
#  'Franklin Gothic Demi',
#  'Century Gothic',
#  'Lucida Sans Unicode',
#  'Leelawadee UI',
#  'Corbel',
#  'Calibri',
#  'Garamond',
#  'Segoe UI Symbol',
#  'Malgun Gothic',
#  'Century Schoolbook',
#  'Malgun Gothic',
#  'Engravers MT',
#  'Tw Cen MT',
#  'Calibri',
#  'Ami R',
#  'Goudy Stout',
#  'Verdana',
#  'Microsoft YaHei',
#  'Perpetua',
#  'Playbill',
#  'Microsoft Tai Le',
#  'Vivaldi',
#  'Calibri',
#  'Segoe Print',
#  'Cambria',
#  'Sitka Small',
#  'Consolas',
#  'Elephant',
#  'Haettenschweiler',
#  'Rockwell Condensed',
#  'Rockwell Extra Bold',
#  'Book Antiqua',
#  'Wingdings',
#  'Candara',
#  'Impact',
#  'Microsoft JhengHei',
#  'Wide Latin',
#  'Maiandra GD',
#  'OCR A Extended',
#  'Century',
#  'Segoe UI',
#  'Bodoni MT',
#  'Lucida Fax',
#  'Colonna MT',
#  'Book Antiqua',
#  'Corbel',
#  'Gill Sans MT',
#  'Algerian',
#  'Myanmar Text',
#  'Cambria',
#  'Eras Light ITC',
#  'Nirmala UI',
#  'Arial',
#  'Lucida Calligraphy',
#  'Bell MT',
#  'HCR Dotum',
#  'Impact',
#  'Segoe MDL2 Assets',
#  'Times New Roman',
#  'Gadugi',
#  'Sylfaen',
#  'Felix Titling',
#  'Corbel',
#  'Corbel',
#  'HYShortSamul-Medium',
#  'MS Reference Sans Serif',
#  'Times New Roman',
#  'Mistral',
#  'Goudy Old Style',
#  'Palatino Linotype',
#  'Courier New',
#  'Gill Sans Ultra Bold',
#  'Chiller',
#  'Colonna MT',
#  'Imprint MT Shadow',
#  'Tw Cen MT Condensed Extra Bold',
#  'Gulim',
#  'Franklin Gothic Demi',
#  'Segoe UI Emoji',
#  'Magneto',
#  'Trebuchet MS',
#  'Courier New',
#  'Tw Cen MT Condensed',
#  'Corbel',
#  'Perpetua',
#  'Gigi',
#  'Constantia',
#  'Comic Sans MS',
#  'Vladimir Script',
#  'Courier New',
#  'Lucida Console',
#  'Cascadia Mono',
#  'Microsoft JhengHei',
#  'Trebuchet MS',
#  'Cooper Black',
#  'Headline R',
#  'Californian FB',
#  'Britannic Bold',
#  'Goudy Old Style',
#  'Calisto MT',
#  'Segoe UI',
#  'Century Schoolbook',
#  'Malgun Gothic',
#  'HoloLens MDL2 Assets',
#  'Bodoni MT',
#  'Calisto MT',
#  'Ebrima',
#  'Brush Script MT',
#  'Perpetua Titling MT',
#  'Bodoni MT',
#  'Calibri',
#  'Verdana',
#  'Wingdings 2',
#  'NewJumja',
#  'HYPMokGak-Bold',
#  'Gill Sans Ultra Bold Condensed',
#  'Wide Latin',
#  'Microsoft Uighur',
#  'MT Extra',
#  'Leelawadee UI',
#  'Myanmar Text',
#  'Jokerman',
#  'Bookman Old Style',
#  'Lucida Fax',
#  'Bell MT',
#  'Gadugi',
#  'Bernard MT Condensed',
#  'Georgia',
#  'Castellar',
#  'Lucida Sans Typewriter',
#  'Sitka Small',
#  'Segoe Script',
#  'Ebrima',
#  'Goudy Old Style',
#  'Bahnschrift',
#  'Arial',
#  'Blackadder ITC',
#  'Yu Gothic',
#  'Constantia',
#  'Agency FB',
#  'Nirmala UI',
#  'Century Gothic',
#  'Goudy Old Style',
#  'Microsoft YaHei',
#  'Leelawadee',
#  'Bookman Old Style',
#  'Candara',
#  'Times New Roman',
#  'Franklin Gothic Demi',
#  'Blackadder ITC',
#  'Batang',
#  'Sylfaen',
#  'Candara',
#  'Segoe UI',
#  'Broadway',
#  'Rockwell',
#  'Tahoma',
#  'Vladimir Script',
#  'Franklin Gothic Medium Cond',
#  'Brush Script MT',
#  'HYGothic-Extra',
#  'Wingdings 3',
#  'Onyx',
#  'Constantia',
#  'Perpetua',
#  'Californian FB',
#  'Calibri',
#  'Bodoni MT',
#  'Kristen ITC',
#  'Freestyle Script',
#  'Century Gothic',
#  'Tempus Sans ITC',
#  'Rage Italic',
#  'Cambria',
#  'Wingdings 3',
#  'Lucida Bright',
#  'Bell MT',
#  'Bodoni MT',
#  'Tw Cen MT',
#  'Showcard Gothic',
#  'Lucida Calligraphy',
#  'Lucida Sans',
#  'Segoe UI',
#  'Consolas',
#  'Footlight MT Light',
#  'Franklin Gothic Heavy',
#  'Lucida Sans',
#  'Microsoft Sans Serif',
#  'Wingdings',
#  'Sitka Small',
#  'Segoe UI',
#  'Bodoni MT',
#  'Javanese Text',
#  'Eras Demi ITC',
#  'Lucida Sans Typewriter',
#  'Calibri',
#  'Book Antiqua',
#  'Modern No. 20',
#  'Mongolian Baiti',
#  'Sitka Small',
#  'Yu Gothic',
#  'Cambria',
#  'Microsoft Tai Le',
#  'Agency FB',
#  'Times New Roman',
#  'Dubai',
#  'Lucida Bright',
#  'Kunstler Script',
#  'Yu Gothic',
#  'Lucida Bright',
#  'Perpetua',
#  'Palatino Linotype',
#  'Nirmala UI',
#  'Dubai',
#  'Arial',
#  'Javanese Text',
#  'Berlin Sans FB Demi',
#  'Corbel',
#  'Ink Free',
#  'Tahoma',
#  'HYPost-Light',
#  'Stencil',
#  'Lucida Sans',
#  'Microsoft New Tai Lue',
#  'Freestyle Script',
#  'MT Extra',
#  'Cambria',
#  'Baskerville Old Face',
#  'Yu Gothic',
#  'Malgun Gothic',
#  'Californian FB',
#  'Script MT Bold',
#  'Segoe UI',
#  'Old English Text MT',
#  'French Script MT',
#  'Centaur',
#  'Calibri',
#  'Bodoni MT',
#  'Century Gothic',
#  'Candara',
#  'Constantia',
#  'Mistral',
#  'Franklin Gothic Book',
#  'Arial',
#  'Arial',
#  'Modern No. 20',
#  'Poor Richard',
#  'Tw Cen MT',
#  'Century Gothic',
#  'Segoe MDL2 Assets',
#  'Mongolian Baiti',
#  'Segoe UI',
#  'Dubai',
#  'Palace Script MT',
#  'Consolas',
#  'Bookman Old Style',
#  'Corbel',
#  'Georgia',
#  'Tw Cen MT',
#  'Candara',
#  'Monotype Corsiva',
#  'Curlz MT',
#  'Leelawadee UI',
#  'MS Reference Specialty',
#  'HYGungSo-Bold',
#  'Franklin Gothic Heavy',
#  'Dubai',
#  'Batang',
#  'Comic Sans MS',
#  'Verdana',
#  'Franklin Gothic Medium',
#  'Bodoni MT',
#  'Pyunji R',
#  'Harlow Solid Italic',
#  'Constantia',
#  'MS Gothic',
#  'Elephant',
#  'Candara',
#  'Franklin Gothic Demi Cond',
#  'Century Schoolbook',
#  'Copperplate Gothic Light',
#  'Rockwell',
#  'Segoe Print',
#  'Book Antiqua',
#  'Arial Rounded MT Bold',
#  'HYGothic-Medium',
#  'HYHeadLine-Medium',
#  'Arial',
#  'Pristina',
#  'Arial',
#  'Trebuchet MS',
#  'HCR Batang',
#  'Ebrima',
#  'Tw Cen MT',
#  'Segoe Script',
#  'Malgun Gothic',
#  'Ami R',
#  'Segoe Script',
#  'Bookman Old Style',
#  'Constantia',
#  'Monotype Corsiva',
#  'Corbel',
#  'MS Outlook',
#  'Century Schoolbook',
#  'Centaur',
#  'Copperplate Gothic Bold',
#  'HYHeadLine-Medium',
#  'Segoe UI Historic',
#  'Corbel',
#  'Courier New',
#  'Gill Sans MT Condensed',
#  'Palatino Linotype',
#  'Cascadia Mono',
#  'Calibri',
#  'Candara',
#  'SimSun',
#  'Yet R',
#  'HYSinMyeongJo-Medium',
#  'Rockwell Extra Bold',
#  'Informal Roman',
#  'Gabriola',
#  'Courier New',
#  'HYGothic-Medium',
#  'Myanmar Text',
#  'Broadway',
#  'Verdana',
#  'Segoe UI',
#  'Onyx',
#  'Arial',
#  'Lucida Fax',
#  'Bell MT',
#  'Nirmala UI',
#  'Microsoft JhengHei',
#  'Yu Gothic',
#  'Consolas',
#  'Dubai',
#  'Rockwell Condensed',
#  'Forte',
#  'Candara',
#  'Microsoft YaHei',
#  'Berlin Sans FB',
#  'Harlow Solid Italic',
#  'Constantia',
#  'Copperplate Gothic Bold',
#  'Magic R',
#  'Tw Cen MT Condensed',
#  'Microsoft PhagsPa',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Eras Bold ITC',
#  'Arial',
#  'Old English Text MT',
#  'Lucida Fax',
#  'Calibri',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Rockwell',
#  'Informal Roman',
#  'Lucida Sans',
#  'Tempus Sans ITC',
#  'Bernard MT Condensed',
#  'Microsoft PhagsPa',
#  'Garamond',
#  'Segoe UI',
#  'MS Reference Sans Serif',
#  'Showcard Gothic',
#  'SimSun-ExtB',
#  'Microsoft Uighur',
#  'Franklin Gothic Heavy',
#  'Cascadia Code',
#  'Georgia',
#  'Britannic Bold',
#  'Perpetua',
#  'Tw Cen MT Condensed',
#  'Nirmala UI',
#  'Yu Gothic',
#  'Lucida Fax',
#  'Segoe UI',
#  'Tw Cen MT Condensed',
#  'Bodoni MT',
#  'Papyrus',
#  'Segoe UI',
#  'Microsoft Tai Le',
#  'Century Gothic',
#  'Microsoft JhengHei',
#  'Arial',
#  'Cambria',
#  'Segoe UI',
#  'Microsoft JhengHei',
#  'Leelawadee UI',
#  'Tw Cen MT Condensed Extra Bold',
#  'HYGungSo-Bold',
#  'Times New Roman',
#  'Lucida Handwriting',
#  'Trebuchet MS',
#  'Bodoni MT',
#  'OCR A Extended',
#  'Segoe UI',
#  'Bodoni MT',
#  'Playbill',
#  'Leelawadee UI',
#  'Comic Sans MS',
#  'Bookshelf Symbol 7',
#  'Arial',
#  'Headline R',
#  'Bodoni MT',
#  'Wingdings 2',
#  'Gadugi',
#  'Perpetua',
#  'Tw Cen MT',
#  'Lucida Handwriting',
#  'Microsoft Uighur',
#  'Segoe UI',
#  'Lucida Sans Typewriter',
#  'Goudy Old Style',
#  'Century Gothic',
#  'Courier New',
#  'Elephant',
#  'Sitka Small',
#  'Segoe UI',
#  'Tahoma',
#  'Bauhaus 93',
#  'Bookshelf Symbol 7',
#  'Georgia',
#  'Leelawadee',
#  'Microsoft Himalaya',
#  'Tw Cen MT',
#  'Century Schoolbook',
#  'Microsoft PhagsPa',
#  'Franklin Gothic Demi',
#  'Palatino Linotype',
#  'Calisto MT',
#  'Bahnschrift',
#  'Segoe UI',
#  'Magneto',
#  'Comic Sans MS',
#  'Bookman Old Style',
#  'Maiandra GD',
#  'Marlett',
#  'Ravie',
#  'Bauhaus 93',
#  'Verdana',
#  'Bodoni MT',
#  'Rockwell',
#  'Vivaldi',
#  'Palatino Linotype',
#  'Rockwell Condensed',
#  'Lucida Sans Typewriter',
#  'Century',
#  'Papyrus',
#  'Goudy Old Style',
#  'Juice ITC',
#  'Eras Bold ITC',
#  'Perpetua',
#  'Lucida Sans Typewriter',
#  'Segoe UI',
#  'Candara',
#  'Consolas',
#  'Sitka Small',
#  'Franklin Gothic Book',
#  'Parchment',
#  'Bodoni MT',
#  'HCR Dotum',
#  'HYMyeongJo-Extra',
#  'Calisto MT',
#  'Castellar',
#  'Franklin Gothic Demi Cond',
#  'Sitka Small',
#  'Times New Roman',
#  'SimSun-ExtB',
#  'HYPost-Medium',
#  'Tahoma',
#  'MoeumT R',
#  'Perpetua Titling MT',
#  'Edwardian Script ITC',
#  'Gill Sans MT',
#  'Lucida Bright',
#  'HYPost-Medium',
#  'Symbol',
#  'Bradley Hand ITC',
#  'Matura MT Script Capitals',
#  'Calibri',
#  'Forte',
#  'Arial',
#  'Arial',
#  'Snap ITC',
#  'Webdings',
#  'Rage Italic',
#  'Eras Demi ITC',
#  'Microsoft Yi Baiti',
#  'Gloucester MT Extra Condensed',
#  'Tw Cen MT',
#  'Segoe UI',
#  'Dubai',
#  'Rockwell',
#  'Calisto MT',
#  'Microsoft YaHei',
#  'MingLiU-ExtB',
#  'Symbol',
#  'Gadugi',
#  'Lucida Fax',
#  'Bradley Hand ITC',
#  'Consolas',
#  'Segoe UI',
#  'Gill Sans MT',
#  'Verdana',
#  'Ink Free',
#  'Ravie',
#  'Arial',
#  'Trebuchet MS',
#  'Bodoni MT',
#  'Yu Gothic',
#  'Comic Sans MS',
#  'High Tower Text',
#  'Matura MT Script Capitals',
#  'Gill Sans MT',
#  'Algerian',
#  'HYGraphic-Medium',
#  'Courier New',
#  'Comic Sans MS',
#  'Bookman Old Style']

# %%
plt.plot(x,y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
